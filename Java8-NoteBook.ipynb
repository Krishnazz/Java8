// %%
/* Given two Strings Anagram or not */

import java.util.*;
import java.util.Arrays;
import java.util.stream.Collectors;

//public class Anagram {

	//public static void main(String[] args) {
		// TODO Auto-generated method stub
		String str1="Silent";
		String str2="listen";
		List<String>  a=Arrays.stream(str1.split("")).sorted().collect(Collectors.toList());
		List<String>  b=Arrays.stream(str1.split("")).sorted().collect(Collectors.toList());
		if(a.equals(b))
			System.out.println("YES");
		else
			System.out.println("NO");
	//}

//}
// Out:
// YES

// %%
/*Count of Occurance of each character in the String  */

import java.util.*;
import java.util.function.Function;
import java.util.stream.Collectors;


		String str="Krishnaa";
		Map<String,Long> map=Arrays.stream(str.split("")).collect(Collectors.groupingBy(Function.identity(),Collectors.counting()));
		System.out.println(map);
// Out:
// {a=2, r=1, s=1, h=1, i=1, K=1, n=1}

// %%
/* Decimal number reverse*/

List<Double> al=Arrays.asList(2.3,3.32,5.2,5.32,21.3,5.32,1.43);
		al.stream().sorted(Comparator.reverseOrder()).forEach(System.out::println);
// Out:
// 21.3
// 5.32
// 5.32
// 5.2
// 3.32
// 2.3
// 1.43

// %%
/* KeyValue pair Key - String Value - Length of the String */

import java.util.*;
ArrayList<String> al=new ArrayList<>();
		
		al.add("Sam");
		al.add("Kaira");
		al.add("Kayadu");
		al.add("Pooja");
		al.add("Rukmini");
		
		Map<String ,Integer>map=al.stream().collect(Collectors.toMap(i->i, i->i.length()));
		System.out.print(map);
// Out:
// {Rukmini=7, Kayadu=6, Kaira=5, Pooja=5, Sam=3}

// %%
/*Map-List -- Map contains Key as String value as List */

Map<String,List<String>>map=new HashMap<>();
		map.put("Fruits", Arrays.asList("Apple","Orange","Mango"));
		map.put("Vegetables", Arrays.asList("Carrot","potato","beetroot"));
		map.forEach((key,value)->{
			System.out.println("KEY -- "+key);
			value.forEach(i->System.out.println(i));
		});
// Out:
// KEY -- Vegetables
// Carrot
// potato
// beetroot
// KEY -- Fruits
// Apple
// Orange
// Mango

// %%
/* Max 3 Min 3 */

List<Integer> al= Arrays.asList(1,2,5,3,8,6,3,7,9);
		al.stream().sorted().limit(3).forEach(System.out::println);
		System.out.println("---");
		al.stream().sorted(Comparator.reverseOrder()).limit(3).forEach(System.out::println);
// Out:
// 1
// 2
// 3
// ---
// 9
// 8
// 7

// %%
/* Merge two Unsorted Array without Duplicates */

import java.util.stream.Stream;
import java.util.Arrays;
Integer[] Array1= {4,3,6,2,7,1};
		Integer[] Array2= {5,3,1,6,3,2};
		Integer[] array=Stream.concat(Arrays.stream(Array1), Arrays.stream(Array2)).distinct().sorted().toArray(Integer[]::new);
		for(int a:array) {
			System.out.println(a);
		}
// Out:
// 1
// 2
// 3
// 4
// 5
// 6
// 7

// %%
/* Palindrome check */

import java.util.stream.IntStream;
import java.util.Arrays;

String str="madam";
		
		if(IntStream.range(0, str.length()/2).allMatch(i->str.charAt(i)==str.charAt(str.length()-i-1)))
			System.out.println("Palindrome");
		else
			System.out.println("Not a Palindrome");
// Out:
// Palindrome
